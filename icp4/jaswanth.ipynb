# %%
# %tensorflow_version 1.15
import tensorflow as tf
from keras import Sequential
from keras.datasets import mnist
import numpy as np
from keras.layers import Dense
from keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator, load_img
import os
import matplotlib.pyplot as plt
from keras.layers import Dense, Flatten, Dropout, Input, BatchNormalization
from keras.constraints import maxnorm
from keras.models import Model
from keras.optimizers import SGD, Adam
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.utils import np_utils
from keras import backend as K
K.common.image_dim_ordering()
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.15`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# Using TensorFlow backend.
# 'tf'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from PIL import Image
import glob
import cv2
train_images=[]
for filename in glob.glob('/content/drive/My Drive/deeplearningicp4/aeroplane/train/*.jpg'):
    img_normal = cv2.imread(filename)
    output = cv2.resize(img_normal, (50,50))
    train_images.append([output,0])

# %%
from PIL import Image
import glob
import cv2
for filename in glob.glob('/content/drive/My Drive/deeplearningicp4/dogs/train/*.jpg'):
    img_normal = cv2.imread(filename)
    output = cv2.resize(img_normal,(50,50))
    train_images.append([output,1])

# %%
import random
random.shuffle(train_images)

# %%
x_train=[]
y_train=[]
for im,label in train_images:
  x_train.append(im)
  y_train.append(label)

# %%
x_train=np.array(x_train).reshape(-1,50,50,3)

# %%
train_images[0]
# Out:
# [array([[[111, 112,  44],
#          [113, 114,  46],
#          [113, 114,  46],
#          ...,
#          [111, 112,  44],
#          [111, 112,  46],
#          [106, 107,  41]],
#
#         [[116, 117,  49],
#          [113, 114,  46],
#          [113, 114,  46],
#          ...,
#          [113, 114,  46],
#          [112, 113,  47],
#          [111, 112,  46]],
#
#         [[113, 114,  46],
#          [114, 115,  47],
#          [116, 118,  48],
#          ...,
#          [111, 116,  47],
#          [111, 112,  44],
#          [109, 110,  42]],
#
#         ...,
#
#         [[102,  99,  95],
#          [ 98,  95,  91],
#          [119, 115, 110],
#          ...,
#          [103, 106,  44],
#          [100, 105,  44],
#          [ 96, 101,  40]],
#
#         [[116, 110, 103],
#          [112, 110, 107],
#          [100,  98,  97],
#          ...,
#          [101, 106,  45],
#          [101, 106,  45],
#          [ 98, 103,  42]],
#
#         [[105, 100,  94],
#          [117, 114, 112],
#          [106, 104, 103],
#          ...,
#          [100, 105,  44],
#          [ 99, 102,  46],
#          [ 97, 101,  45]]], dtype=uint8), 1]

# %%
type(x_train)
x_train.shape
x_train[0]
# Out:
# array([[[111, 112,  44],
#         [113, 114,  46],
#         [113, 114,  46],
#         ...,
#         [111, 112,  44],
#         [111, 112,  46],
#         [106, 107,  41]],
#
#        [[116, 117,  49],
#         [113, 114,  46],
#         [113, 114,  46],
#         ...,
#         [113, 114,  46],
#         [112, 113,  47],
#         [111, 112,  46]],
#
#        [[113, 114,  46],
#         [114, 115,  47],
#         [116, 118,  48],
#         ...,
#         [111, 116,  47],
#         [111, 112,  44],
#         [109, 110,  42]],
#
#        ...,
#
#        [[102,  99,  95],
#         [ 98,  95,  91],
#         [119, 115, 110],
#         ...,
#         [103, 106,  44],
#         [100, 105,  44],
#         [ 96, 101,  40]],
#
#        [[116, 110, 103],
#         [112, 110, 107],
#         [100,  98,  97],
#         ...,
#         [101, 106,  45],
#         [101, 106,  45],
#         [ 98, 103,  42]],
#
#        [[105, 100,  94],
#         [117, 114, 112],
#         [106, 104, 103],
#         ...,
#         [100, 105,  44],
#         [ 99, 102,  46],
#         [ 97, 101,  45]]], dtype=uint8)

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train[50,:,:])
plt.title('Ground Truth : {}'.format(y_train[50]))
plt.show()

# %%
test_images=[]
for filename in glob.glob('/content/drive/My Drive/deeplearningicp4/aeroplane/test/*.jpg'): 
    img_normal = cv2.imread(filename)
    output = cv2.resize(img_normal, (50,50))
    test_images.append([output,0])

# %%
for filename in glob.glob('/content/drive/My Drive/deeplearningicp4/dogs/test/*.jpg'): 
    img_normal = cv2.imread(filename)
    #print(im.shape)
    #print(type(im.shape))
    output = cv2.resize(img_normal, (50,50))
    test_images.append([output,1])

# %%
random.shuffle(test_images)

# %%
x_test=[]
y_test=[]
for im,label in test_images:
  x_test.append(im)
  y_test.append(label)

# %%
x_test=np.array(x_test).reshape(-1,50,50,3)

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
num_classes = y_test.shape[1]

# %%
model = Sequential()
model.add(Conv2D(256, (3, 3), input_shape=(x_train.shape[1:]), padding='same', activation='relu'))
model.add(Dropout(0.5))
model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(512, activation='relu', kernel_constraint=maxnorm(3)))
model.add(Dropout(0.3))
model.add(Dense(num_classes, activation='softmax'))
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
epochs = 20
lrate = 0.001
decay = lrate/epochs
sgd = Adam(lr=lrate)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=epochs, batch_size=128)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 400 samples, validate on 371 samples
# Epoch 1/20
# 400/400 [==============================] - 8s 20ms/step - loss: 14.4405 - accuracy: 0.4925 - val_loss: 0.6900 - val_accuracy: 0.5067
# Epoch 2/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.6210 - accuracy: 0.5725 - val_loss: 0.6920 - val_accuracy: 0.5472
# Epoch 3/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.6087 - accuracy: 0.5600 - val_loss: 0.6952 - val_accuracy: 0.3881
# Epoch 4/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.4738 - accuracy: 0.7225 - val_loss: 1.6056 - val_accuracy: 0.4636
# Epoch 5/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.4050 - accuracy: 0.8000 - val_loss: 1.4577 - val_accuracy: 0.4663
# Epoch 6/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.3181 - accuracy: 0.8725 - val_loss: 1.9780 - val_accuracy: 0.4582
# Epoch 7/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.2911 - accuracy: 0.9000 - val_loss: 0.9502 - val_accuracy: 0.5121
# Epoch 8/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.2577 - accuracy: 0.9025 - val_loss: 1.5042 - val_accuracy: 0.4663
# Epoch 9/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.2292 - accuracy: 0.9200 - val_loss: 0.7164 - val_accuracy: 0.6739
# Epoch 10/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.2371 - accuracy: 0.9150 - val_loss: 1.6144 - val_accuracy: 0.4663
# Epoch 11/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.2358 - accuracy: 0.9100 - val_loss: 0.6402 - val_accuracy: 0.7062
# Epoch 12/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.2143 - accuracy: 0.9075 - val_loss: 0.9418 - val_accuracy: 0.5499
# Epoch 13/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.1656 - accuracy: 0.9475 - val_loss: 1.0063 - val_accuracy: 0.5849
# Epoch 14/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.1524 - accuracy: 0.9425 - val_loss: 0.8960 - val_accuracy: 0.6658
# Epoch 15/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.1466 - accuracy: 0.9375 - val_loss: 0.9218 - val_accuracy: 0.6685
# Epoch 16/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.1250 - accuracy: 0.9450 - val_loss: 0.9808 - val_accuracy: 0.6199
# Epoch 17/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.1159 - accuracy: 0.9575 - val_loss: 0.9046 - val_accuracy: 0.6658
# Epoch 18/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.1041 - accuracy: 0.9650 - val_loss: 1.3210 - val_accuracy: 0.5606
# Epoch 19/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.1120 - accuracy: 0.9600 - val_loss: 1.0751 - val_accuracy: 0.6226
# Epoch 20/20
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0905 - accuracy: 0.9700 - val_loss: 1.0084 - val_accuracy: 0.6631

# %%
import pickle
with open("/content/drive/My Drive/deeplearningicp4/jaswanth.pk2",'wb') as file:
      pickle.dump(model,file)

# %%
x=model.predict_classes(x_train[[50],:])

# %%
print(x[0])
# Out:
# 0
